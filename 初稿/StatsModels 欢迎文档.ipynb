# %% [markdown]
# **欢迎使用Statsmodels的文档**
#
# statsmodels是一个Python模块，提供用于估计许多不同的统计模型以及进行统计测试和统计数据探索的类和函数。每个估算器都有大量的结果统计信息列表。将结果与现有统计数据包进行测试，以确保结果正确。该软件包是根据开源的经过修改的BSD（3条款）许可发布的。在线文档托管在statsmodels.org上。

# %% [markdown]
# **statsmodels**
#
# 与scikit-learn比较，statsmodels包含经典统计学和经济计量学的算法。包括如下子模块：
#
# 回归模型：线性回归，广义线性模型，健壮线性模型，线性混合效应模型等等。
#
# 方差分析（ANOVA）。
#
# 时间序列分析：AR，ARMA，ARIMA，VAR和其它模型。
#
# 非参数方法： 核密度估计，核回归。
#
# 统计模型结果可视化。
#
# **statsmodels更关注统计推断，提供不确定估计和参数p-value。相反的，scikit-learn注重预测。**

# %% [markdown]
# **最小的例子**
#
# statsmodels从版本0.5.0开始，你就可以将R-style公式与pandas.DataFrame一起使用以拟合模型。下方是一个使用普通最小二乘法的简单示例：
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 您也可以使用numpy数组代替公式：
# ![image.png](attachment:image.png)
